# %% [markdown]
# # Capstone Project - Evaluating the best Neighborhood in Ontario, Canada to immigrate to

# %% [markdown]
# ## Shaun Diplock - 22nd March 2021

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# The problem / challenge addressed in this report and study is a very personal one; the target audience is myself and my future wife and family. Therefore, this 'business problem' is a fairly unconventional one, as I am performing this study for myself as the main stakeholder. I'll attempt to keep personal details and information minimal throughout this report, however as a natural consequence of the subject matter I will occasionally reference items of personal interest.
#
# I met my fiance over 5 years ago in Ottawa, Canada, whilst I was working in the area on on a business trip. I live in England, and work as a system development manager and engineer, and frequently have to travel abroad for client site visits and buisness meetings. Our long-distance relationship has developed to the point where we our now engaged, and I am actively trying to immigrate to Canada so we can seriously start our life together.
#
# Moving to another country is a daunting prospect, and one that merits time and research into identifying the best area for both of us. Naturally, I am very anxious (but also excited) for what the future holds - this project represents a very real, genuine attempt to evaluate some areas that will maximise the chance of our move and choice being a success.
#
# The minimum criteria for us is as follows:
#
# 1. Within a 60 minute drive (approximately 60 km) of Smiths Falls, Ontario (this is where my fiance currently works).
# 2. We do not want to live in a very small town - the town / city must contain more than 1000 residents.
# 3. We do not want to live in a very busy downtown area.
#
# Providing the above minimum criteria are met, towns / cities / neighboorhoods will be ranked using the following attributes:
#
# 1. The amount of restuarants and bars in the town / city, and their ratings.
# 2. The amount of gyms / fitness studios, and their ratings.
# 3. The amount of outdoor spaces, such as parks and trails.
# 4. The amount of shopping outlets and retail stores.
# 5. The average cost of housing in the area.
#
# With the above critieria evaluated we will hopefully be able to identify some suitable areas for us to move to when I immigrate, to maximise the chance of our future life together being happy and successful.

# %% [markdown]
# ## 2. Data Acquisition and Preparation

# %% [markdown]
# This problem will be evaluated using Foresquare location data. This data will first be leveraged in order to evaluate the areas, towns, cities and neighborhoods that meet the minimum acceptable criteria. The Foresquare location data will then be used to evaluate our preffered neighborhood attributes.
#
# This data can be called to provide lots of meaningful and revelant information - for instance it can be used to examine and cluster the frequency of various amneties in an area, as shown by the following results from a previous and related exercise:
#
# ![alt text](https://github.com/ShaunDiplock/Coursera_Capstone/blob/main/Neighborhood%20data%20example.PNG?raw=true "Example clustered neighborhood data")
#
# In addition to the Foresquare data, I will also use the [MLS Home Price Index (HPI)](https://www.crea.ca/housing-market-stats/mls-home-price-index/) data from the [Canadian Real Estate Association](https://www.crea.ca/) website in order to evaluate the average price of housing in each area. This data is available for download using this link: https://www.crea.ca/hpi-tools-terms-of-use/.
#
# Ultimately, I will be using all of this data to assign each area a 'weighted score' to help form a list of the best three suitable neighborhoods, with some final discussion about the pros and cons of each area.

# %%
#import cell

import pandas as pd
#import geopandas as gpd
#import geopy
#from geopy.geocoders import Nominatim
#from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
#import plotly_express as px
#import tqdm
#from tqdm._tqdm_notebook import tqdm_notebook

import json # library to handle JSON files
import requests # library to handle requests

# %%
# figure out how to filter 100km around ottawa international airport

#GPS coordinates of Ottawa Macdonald–Cartier International Airport, Canada. Latitude: 45.3202 Longitude: -75.6682.

url='https://reverse.geocoder.ls.hereapi.com/6.2/reversegeocode.json?apiKey=FQRQJu970l9gXA0QmJUcKajBGrOKIk2XlK428fvC9NI&mode=retrieveAreas&level=city&gen=9&prox=45.3203,-75.6682,100000'

url2='https://revgeocode.search.hereapi.com/v1/revgeocode?apikey=apiKey=FQRQJu970l9gXA0QmJUcKajBGrOKIk2XlK428fvC9NI&mode=retrieveAreas&level=city&gen=9&prox=45.3203,-75.6682,100000'


requests.get(url).json()["Response"]['View']#['City']
# Out:
# [{'_type': 'SearchResultsViewType',
#   'ViewId': 0,
#   'Result': [{'Relevance': 1.0,
#     'Distance': -11860.7,
#     'Direction': 351.0,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_A5v.FK2acUrKduZfMR5j1C',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.42179, 'Longitude': -75.69116},
#      'MapView': {'TopLeft': {'Latitude': 45.53654, 'Longitude': -76.35577},
#       'BottomRight': {'Latitude': 44.962, 'Longitude': -75.24603}},
#      'Address': {'Label': 'Ottawa, ON, Canada',
#       'Country': 'CAN',
#       'State': 'ON',
#       'County': 'Ottawa',
#       'City': 'Ottawa',
#       'PostalCode': 'K1P',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Ontario', 'key': 'StateName'},
#        {'value': 'Ottawa', 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '829514632',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21041603',
#       'CountyId': '21086533',
#       'CityId': '21086534'}}},
#    {'Relevance': 1.0,
#     'Distance': 11860.8,
#     'Direction': 344.7,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_UKEut9rSdPX5FkY49XElDA',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.4283, 'Longitude': -75.71037},
#      'MapView': {'TopLeft': {'Latitude': 45.59904, 'Longitude': -75.90842},
#       'BottomRight': {'Latitude': 45.37274, 'Longitude': -75.34952}},
#      'Address': {'Label': 'Gatineau, QC, Canada',
#       'Country': 'CAN',
#       'State': 'QC',
#       'County': 'Gatineau',
#       'City': 'Gatineau',
#       'PostalCode': 'J8X',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Québec', 'key': 'StateName'},
#        {'value': 'Gatineau', 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '844051649',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21055262',
#       'CountyId': '21157550',
#       'CityId': '21157554'}}},
#    {'Relevance': 1.0,
#     'Distance': 18398.0,
#     'Direction': 335.2,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_33ZpOJEASHFjPrgcNF.EvB',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.52698, 'Longitude': -75.80437},
#      'MapView': {'TopLeft': {'Latitude': 45.61579, 'Longitude': -75.92947},
#       'BottomRight': {'Latitude': 45.45925, 'Longitude': -75.73982}},
#      'Address': {'Label': 'Chelsea, QC, Canada',
#       'Country': 'CAN',
#       'State': 'QC',
#       'County': "Les Collines-de-l'Outaouais",
#       'City': 'Chelsea',
#       'PostalCode': 'J9B',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Québec', 'key': 'StateName'},
#        {'value': "Les Collines-de-l'Outaouais", 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '119635783',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21055262',
#       'CountyId': '21159500',
#       'CityId': '21166098'}}},
#    {'Relevance': 1.0,
#     'Distance': 18962.6,
#     'Direction': 105.8,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_-wQumuoeKfVnYABRsotfSC',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.25812, 'Longitude': -75.35879},
#      'MapView': {'TopLeft': {'Latitude': 45.35619, 'Longitude': -75.42594},
#       'BottomRight': {'Latitude': 45.18209, 'Longitude': -75.20091}},
#      'Address': {'Label': 'Russell, ON, Canada',
#       'Country': 'CAN',
#       'State': 'ON',
#       'County': 'Prescott and Russell',
#       'City': 'Russell',
#       'PostalCode': 'K4R',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Ontario', 'key': 'StateName'},
#        {'value': 'Prescott and Russell', 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '119165544',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21041603',
#       'CountyId': '21086536',
#       'CityId': '21159026'}}},
#    {'Relevance': 1.0,
#     'Distance': 20107.6,
#     'Direction': 306.1,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_cleGmWvwKhsDrCLoc0cSQC',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.55756, 'Longitude': -76.13545},
#      'MapView': {'TopLeft': {'Latitude': 45.68296, 'Longitude': -76.32327},
#       'BottomRight': {'Latitude': 45.40284, 'Longitude': -75.89719}},
#      'Address': {'Label': 'Pontiac, QC, Canada',
#       'Country': 'CAN',
#       'State': 'QC',
#       'County': "Les Collines-de-l'Outaouais",
#       'City': 'Pontiac',
#       'PostalCode': 'J0X',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Québec', 'key': 'StateName'},
#        {'value': "Les Collines-de-l'Outaouais", 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '973314347',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21055262',
#       'CountyId': '21159500',
#       'CityId': '21166104'}}},
#    {'Relevance': 1.0,
#     'Distance': 22921.5,
#     'Direction': 178.2,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_wOaE3bnm5tDiig5ofzSayA',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.02343, 'Longitude': -75.65487},
#      'MapView': {'TopLeft': {'Latitude': 45.11675, 'Longitude': -75.82125},
#       'BottomRight': {'Latitude': 44.84422, 'Longitude': -75.48459}},
#      'Address': {'Label': 'North Grenville, ON, Canada',
#       'Country': 'CAN',
#       'State': 'ON',
#       'County': 'Leeds and Grenville',
#       'City': 'North Grenville',
#       'PostalCode': 'K0G',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Ontario', 'key': 'StateName'},
#        {'value': 'Leeds and Grenville', 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '133109588',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21041603',
#       'CountyId': '21086548',
#       'CityId': '21158627'}}},
#    {'Relevance': 1.0,
#     'Distance': 22968.0,
#     'Direction': 340.6,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_39oHs4CQP9bg0YtLBh6MkC',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.54984, 'Longitude': -75.78348},
#      'MapView': {'TopLeft': {'Latitude': 45.63938, 'Longitude': -75.90188},
#       'BottomRight': {'Latitude': 45.50659, 'Longitude': -75.68258}},
#      'Address': {'Label': 'Cantley, QC, Canada',
#       'Country': 'CAN',
#       'State': 'QC',
#       'County': "Les Collines-de-l'Outaouais",
#       'City': 'Cantley',
#       'PostalCode': 'J8V',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Québec', 'key': 'StateName'},
#        {'value': "Les Collines-de-l'Outaouais", 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '119272236',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21055262',
#       'CountyId': '21159500',
#       'CityId': '21166096'}}},
#    {'Relevance': 1.0,
#     'Distance': 25636.1,
#     'Direction': 352.5,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_GxD2Q54g.wOisOvGVXxRRA',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.66451, 'Longitude': -75.73345},
#      'MapView': {'TopLeft': {'Latitude': 45.83331, 'Longitude': -75.83203},
#       'BottomRight': {'Latitude': 45.55063, 'Longitude': -75.53227}},
#      'Address': {'Label': 'Val-des-Monts, QC, Canada',
#       'Country': 'CAN',
#       'State': 'QC',
#       'County': "Les Collines-de-l'Outaouais",
#       'City': 'Val-des-Monts',
#       'PostalCode': 'J8N',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Québec', 'key': 'StateName'},
#        {'value': "Les Collines-de-l'Outaouais", 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '1048113823',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21055262',
#       'CountyId': '21159500',
#       'CityId': '21166106'}}},
#    {'Relevance': 1.0,
#     'Distance': 26088.4,
#     'Direction': 136.1,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_EUuXk0NTtZn0WOP8A8OyeC',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.08373, 'Longitude': -75.34666},
#      'MapView': {'TopLeft': {'Latitude': 45.2177, 'Longitude': -75.59505},
#       'BottomRight': {'Latitude': 44.95555, 'Longitude': -75.15668}},
#      'Address': {'Label': 'North Dundas, ON, Canada',
#       'Country': 'CAN',
#       'State': 'ON',
#       'County': 'Stormont, Dundas and Glengarry',
#       'City': 'North Dundas',
#       'PostalCode': 'K0C',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Ontario', 'key': 'StateName'},
#        {'value': 'Stormont, Dundas and Glengarry', 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '716207722',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21041603',
#       'CountyId': '21086539',
#       'CityId': '21159200'}}},
#    {'Relevance': 1.0,
#     'Distance': 26758.7,
#     'Direction': 29.0,
#     'MatchLevel': 'city',
#     'MatchQuality': {'Country': 1.0,
#      'State': 1.0,
#      'County': 1.0,
#      'City': 1.0,
#      'PostalCode': 1.0},
#     'Location': {'LocationId': 'NT_ng57MEkRpmfNAHAqLZQViB',
#      'LocationType': 'area',
#      'DisplayPosition': {'Latitude': 45.61593, 'Longitude': -75.43329},
#      'MapView': {'TopLeft': {'Latitude': 45.71063, 'Longitude': -75.5577},
#       'BottomRight': {'Latitude': 45.54116, 'Longitude': -75.35526}},
#      'Address': {'Label': "L'Ange-Gardien, QC, Canada",
#       'Country': 'CAN',
#       'State': 'QC',
#       'County': "Les Collines-de-l'Outaouais",
#       'City': "L'Ange-Gardien",
#       'PostalCode': 'J8L',
#       'AdditionalData': [{'value': 'Canada', 'key': 'CountryName'},
#        {'value': 'Québec', 'key': 'StateName'},
#        {'value': "Les Collines-de-l'Outaouais", 'key': 'CountyName'}]},
#      'MapReference': {'ReferenceId': '1048181504',
#       'MapId': 'NAAM21101',
#       'MapVersion': 'Q1/2021',
#       'MapReleaseDate': '2021-03-09',
#       'SideOfStreet': 'neither',
#       'CountryId': '21041602',
#       'StateId': '21055262',
#       'CountyId': '21159500',
#       'CityId': '21159510'}}}]}]
