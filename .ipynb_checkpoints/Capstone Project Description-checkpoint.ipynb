# %% [markdown]
# # Capstone Project - Evaluating the best Neighborhood in Ontario, Canada to immigrate to

# %% [markdown]
# ## Shaun Diplock - 22nd March 2021

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# The problem / challenge addressed in this report and study is a very personal one; the target audience is myself and my future wife and family. Therefore, this 'business problem' is a fairly unconventional one, as I am performing this study for myself as the main stakeholder. I'll attempt to keep personal details and information minimal throughout this report, however as a natural consequence of the subject matter I will occasionally reference items of personal interest.
#
# I met my fiance over 5 years ago in Ottawa, Canada, whilst I was working in the area on on a business trip. I live in England, and work as a system development manager and engineer, and frequently have to travel abroad for client site visits and buisness meetings. Our long-distance relationship has developed to the point where we our now engaged, and I am actively trying to immigrate to Canada so we can seriously start our life together.
#
# Moving to another country is a daunting prospect, and one that merits time and research into identifying the best area for both of us. Naturally, I am very anxious (but also excited) for what the future holds - this project represents a very real, genuine attempt to evaluate some areas that will maximise the chance of our move and choice being a success.
#
# The minimum criteria for us is as follows:
#
# 1. Within a 60 minute drive (approximately 70 km) of Smiths Falls, Ontario (this is where my fiance currently works).
# 2. We do not want to live in Quebec.
# 3. We cannot live in the United States (Smiths Falls is relatively close to the border).
# 4. We do not want to live in a very small town - the town / city must contain more than 2,500 residents.
# 5. We do not want to live in a major city or urban area - the town / city must contain less than 50,000 residents.
#
#
# Providing the above minimum criteria are met, towns / cities / neighboorhoods will be ranked using the following attributes:
#
# 1. The amount of restuarants and bars in the town / city, and their ratings.
# 2. The amount of gyms / fitness studios, and their ratings.
# 3. The amount of outdoor spaces, such as parks and trails.
# 4. The amount of shopping outlets and retail stores.
# 5. The average cost of housing in the area.
# 6. The distance from Smiths Falls, Ontario.
#
# With the above critieria evaluated we will hopefully be able to identify some suitable areas for us to move to when I immigrate, to maximise the chance of our future life together being happy and successful.

# %% [markdown]
# ## 2. Data Acquisition and Preparation

# %% [markdown]
# The source data for this problem will be acquired from [Distantias's location proximity tool](https://www.distantias.com/towns-radius-smiths_falls-ontario-canada.htm). This website provides an easy-to-use tool which can quickly search for all towns, cities and habitated places in proximity to another town or place. It then provides the location data in a convenient .csv file which will be easy to process for the study. Unfortunately, this tool also charges a small fee to use. Despite a thorough search for equivalent libraries / functions and data sources, the ease of which this tool provides outweighed the negative aspect of a small extra charge to access the data.
#
# The reliability of this data seems very good, with transparency about some population data that may be missing from the returned query: *'We don't have data for every town and city in Canada and we specify this with NA in our data table. Population data is sourced from a variety of national and international databases some of which are more current than others. The oldest data set is from 2011 but we do make ongoing updates as new census data is released'.* With this in mind, a provisional review of my queried data did indeed contain hamlets and settlements with no population data; evaluating these manually showed that the settlements are so tiny that no census data has ever been collected from them. Therefore these can be simply dropped from the data as they do not fulfill critierium 4 as detailed above.
#
# This data will then be leveraged using foresquare in order to evaluate the areas, towns, cities and neighborhoods that meet the minimum acceptable criteria. This Foresquare location and venues data will then be used to evaluate our preffered neighborhood attributes.
#
# This data can be called to provide lots of meaningful and revelant information - for instance it can be used to examine and cluster the frequency of various amneties in an area, as shown by the following results from a previous and related exercise:
#
# ![alt text](https://github.com/ShaunDiplock/Coursera_Capstone/blob/main/Neighborhood%20data%20example.PNG?raw=true "Example clustered neighborhood data")
#
# In addition to the Distantia and Foresquare data, I will also use the [MLS Home Price Index (HPI)](https://www.crea.ca/housing-market-stats/mls-home-price-index/) data from the [Canadian Real Estate Association](https://www.crea.ca/) website in order to evaluate the average price of housing in each area. This data is available for download using this link: https://www.crea.ca/hpi-tools-terms-of-use/.
#
# Ultimately, I will be using all of this data to assign each area a 'weighted score' to help form a list of the best three suitable neighborhoods, with some final discussion about the pros and cons of each area.

# %% [markdown]
# # Import required libraries

# %%
import pandas as pd

# %% [markdown]
# # Import Distantias Data

# %%
path='D:\GithubProjects\Coursera_Capstone\smiths_falls_distantias_data.csv'

df_ontariodata = pd.read_csv(path)

df_ontariodata.head(10)
# Out:
#         Town Name                                           Web Link  \
# 0    Smiths Falls  https://www.distantias.com/towns-radius-smiths...
# 1    Merrickville  https://www.distantias.com/towns-radius-merric...
# 2           Perth  https://www.distantias.com/towns-radius-perth-...
# 3          Eloida  https://www.distantias.com/towns-radius-eloida...
# 4  Carleton Place  https://www.distantias.com/towns-radius-carlet...
# 5      Kemptville  https://www.distantias.com/towns-radius-kemptv...
# 6          Crosby  https://www.distantias.com/towns-radius-crosby...
# 7        Richmond  https://www.distantias.com/towns-radius-richmo...
# 8         Newboro  https://www.distantias.com/towns-radius-newbor...
# 9         Almonte  https://www.distantias.com/towns-radius-almont...
#
#    Distance Miles  Distance KM  \
# 0            0.00     0.000000
# 1            9.05    14.564527
# 2           10.67    17.171658
# 3           15.17    24.413688
# 4           17.09    27.503621
# 5           20.39    32.814443
# 6           20.74    33.377712
# 7           21.52    34.632997
# 8           22.71    36.548111
# 9           23.63    38.028704
#
#                Precise Drive time and Directions URL  Approx Drive miles  \
# 0  https://www.distantias.com/distance-from-smith...                0.00
# 1  https://www.distantias.com/distance-from-smith...               10.77
# 2  https://www.distantias.com/distance-from-smith...               13.22
# 3  https://www.distantias.com/distance-from-smith...               18.80
# 4  https://www.distantias.com/distance-from-smith...               21.17
# 5  https://www.distantias.com/distance-from-smith...               24.77
# 6  https://www.distantias.com/distance-from-smith...               25.20
# 7  https://www.distantias.com/distance-from-smith...               26.15
# 8  https://www.distantias.com/distance-from-smith...               27.59
# 9  https://www.distantias.com/distance-from-smith...               28.71
#
#           Approx Drive Time  Assumed Average MPH  Total Minutes    Region  \
# 0   0 hour(s) and 0 minutes                    0            0.0   Ontario
# 1  0 hour(s) and 25 minutes                   26           24.9   Ontario
# 2  0 hour(s) and 21 minutes                   37           21.4   Ontario
# 3  0 hour(s) and 30 minutes                   37           30.5   Ontario
# 4  0 hour(s) and 34 minutes                   37           34.3   Ontario
# 5  0 hour(s) and 27 minutes                   55           27.0   Ontario
# 6  0 hour(s) and 27 minutes                   55           27.5   Ontario
# 7  0 hour(s) and 29 minutes                   55           28.5   Ontario
# 8  0 hour(s) and 30 minutes                   55           30.1   Ontario
# 9  0 hour(s) and 31 minutes                   55           31.3   Ontario
#
#   Country     Population Direction  Latitude  Longitude  Date
# 0  Canada           9403        NE   44.9000   -76.0167  2011
# 1  Canada           3067        NE   44.9167   -75.8333  2011
# 2  Canada           6211        SW   44.8833   -76.2333  2011
# 3  Canada  not available        SE   44.6833   -75.9667  2011
# 4  Canada          10013        NW   45.1333   -76.1333  2011
# 5  Canada           3532        NE   45.0167   -75.6333  2011
# 6  Canada  not available        SW   44.6500   -76.2500  2011
# 7  Canada           3797        NE   45.1833   -75.8333  2011
# 8  Canada  not available        SW   44.6500   -76.3167  2011
# 9  Canada           4752        NW   45.2167   -76.2000  2011

# %%
df_ontariodata.dtypes
# Out:
# Town Name                                 object
# Web Link                                  object
# Distance Miles                           float64
# Distance KM                              float64
# Precise Drive time and Directions URL     object
# Approx Drive miles                       float64
# Approx Drive Time                         object
# Assumed Average MPH                        int64
# Total Minutes                            float64
# Region                                    object
# Country                                   object
# Population                                object
# Direction                                 object
# Latitude                                 float64
# Longitude                                float64
# Date                                       int64
# dtype: object

# %%
df_ontariodata.shape
# Out:
# (135, 16)

# %% [markdown]
# ### Filter for towns that meet criteria 1 (within 70km)

# %%
df1=df_ontariodata[df_ontariodata['Distance KM'] < 70]

df1.shape
# Out:
# (62, 16)

# %%
df1
# Out:
#           Town Name                                           Web Link  \
# 0      Smiths Falls  https://www.distantias.com/towns-radius-smiths...
# 1      Merrickville  https://www.distantias.com/towns-radius-merric...
# 2             Perth  https://www.distantias.com/towns-radius-perth-...
# 3            Eloida  https://www.distantias.com/towns-radius-eloida...
# 4    Carleton Place  https://www.distantias.com/towns-radius-carlet...
# ..              ...                                                ...
# 57      Old Chelsea  https://www.distantias.com/towns-radius-old_ch...
# 58        Luskville  https://www.distantias.com/towns-radius-luskvi...
# 59  Fishers Landing  https://www.distantias.com/towns-radius-fisher...
# 60         Braeside  https://www.distantias.com/towns-radius-braesi...
# 61          Plessis  https://www.distantias.com/towns-radius-plessi...
#
#     Distance Miles  Distance KM  \
# 0             0.00     0.000000
# 1             9.05    14.564527
# 2            10.67    17.171658
# 3            15.17    24.413688
# 4            17.09    27.503621
# ..             ...          ...
# 57           42.58    68.525697
# 58           42.62    68.590071
# 59           42.97    69.153340
# 60           43.34    69.748796
# 61           43.35    69.764889
#
#                 Precise Drive time and Directions URL  Approx Drive miles  \
# 0   https://www.distantias.com/distance-from-smith...                0.00
# 1   https://www.distantias.com/distance-from-smith...               10.77
# 2   https://www.distantias.com/distance-from-smith...               13.22
# 3   https://www.distantias.com/distance-from-smith...               18.80
# 4   https://www.distantias.com/distance-from-smith...               21.17
# ..                                                ...                 ...
# 57  https://www.distantias.com/distance-from-smith...               51.73
# 58  https://www.distantias.com/distance-from-smith...               51.78
# 59  https://www.distantias.com/distance-from-smith...               52.21
# 60  https://www.distantias.com/distance-from-smith...               52.66
# 61  https://www.distantias.com/distance-from-smith...               52.67
#
#            Approx Drive Time  Assumed Average MPH  Total Minutes     Region  \
# 0    0 hour(s) and 0 minutes                    0            0.0    Ontario
# 1   0 hour(s) and 25 minutes                   26           24.9    Ontario
# 2   0 hour(s) and 21 minutes                   37           21.4    Ontario
# 3   0 hour(s) and 30 minutes                   37           30.5    Ontario
# 4   0 hour(s) and 34 minutes                   37           34.3    Ontario
# ..                       ...                  ...            ...        ...
# 57  0 hour(s) and 56 minutes                   55           56.4     Quebec
# 58  0 hour(s) and 56 minutes                   55           56.5     Quebec
# 59  0 hour(s) and 57 minutes                   55           57.0   New York
# 60  0 hour(s) and 57 minutes                   55           57.5    Ontario
# 61  0 hour(s) and 57 minutes                   55           57.5   New York
#
#           Country     Population Direction  Latitude  Longitude  Date
# 0          Canada           9403        NE   44.9000   -76.0167  2011
# 1          Canada           3067        NE   44.9167   -75.8333  2011
# 2          Canada           6211        SW   44.8833   -76.2333  2011
# 3          Canada  not available        SE   44.6833   -75.9667  2011
# 4          Canada          10013        NW   45.1333   -76.1333  2011
# ..            ...            ...       ...       ...        ...   ...
# 57         Canada  not available        NE   45.5000   -75.8167  2011
# 58         Canada  not available        NE   45.5167   -76.0000  2011
# 59  United States             89        SE   44.2782   -76.0083  2011
# 60         Canada           7178        NW   45.4667   -76.4000  2011
# 61  United States            164        SE   44.2847   -75.8458  2011
#
# [62 rows x 16 columns]

# %% [markdown]
# ### Filter for towns that meet criteria 2 (not in Quebec)

# %%
#First remove whitespace which is errorenously present in the .csv file, this step is needed so that filter function works

df1['Region']=df1['Region'].str.strip()

#Then filter for regions not called Quebec
df2=df1[df1['Region'] != "Quebec"]
# Out:
# <ipython-input-129-b7e6aa991e88>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Region']=df1['Region'].str.strip()

# %% [markdown]
# The warning above can be ignored - it's just telling me that I have modified the original dataframe rather than a copy, which is our desired result and *not* a mistake.

# %%
df2.shape
# Out:
# (58, 16)

# %%
df2.tail(10)
# Out:
#                Town Name                                           Web Link  \
# 50       Rockcliffe Park  https://www.distantias.com/towns-radius-rockcl...
# 51          Chesterville  https://www.distantias.com/towns-radius-cheste...
# 52                Madrid  https://www.distantias.com/towns-radius-madrid...
# 53            Waddington  https://www.distantias.com/towns-radius-waddin...
# 54               Redwood  https://www.distantias.com/towns-radius-redwoo...
# 55        Mountain Grove  https://www.distantias.com/towns-radius-mounta...
# 56  Thousand Island Park  https://www.distantias.com/towns-radius-thousa...
# 59       Fishers Landing  https://www.distantias.com/towns-radius-fisher...
# 60              Braeside  https://www.distantias.com/towns-radius-braesi...
# 61               Plessis  https://www.distantias.com/towns-radius-plessi...
#
#     Distance Miles  Distance KM  \
# 50           41.30    66.465742
# 51           41.40    66.626676
# 52           41.69    67.093385
# 53           41.75    67.189945
# 54           42.19    67.898055
# 55           42.50    68.396950
# 56           42.51    68.413043
# 59           42.97    69.153340
# 60           43.34    69.748796
# 61           43.35    69.764889
#
#                 Precise Drive time and Directions URL  Approx Drive miles  \
# 50  https://www.distantias.com/distance-from-smith...               50.18
# 51  https://www.distantias.com/distance-from-smith...               50.30
# 52  https://www.distantias.com/distance-from-smith...               50.65
# 53  https://www.distantias.com/distance-from-smith...               50.73
# 54  https://www.distantias.com/distance-from-smith...               51.26
# 55  https://www.distantias.com/distance-from-smith...               51.64
# 56  https://www.distantias.com/distance-from-smith...               51.65
# 59  https://www.distantias.com/distance-from-smith...               52.21
# 60  https://www.distantias.com/distance-from-smith...               52.66
# 61  https://www.distantias.com/distance-from-smith...               52.67
#
#            Approx Drive Time  Assumed Average MPH  Total Minutes    Region  \
# 50  0 hour(s) and 55 minutes                   55           54.7   Ontario
# 51  0 hour(s) and 55 minutes                   55           54.9   Ontario
# 52  0 hour(s) and 55 minutes                   55           55.3  New York
# 53  0 hour(s) and 55 minutes                   55           55.3  New York
# 54  0 hour(s) and 56 minutes                   55           55.9  New York
# 55  0 hour(s) and 56 minutes                   55           56.3   Ontario
# 56  0 hour(s) and 56 minutes                   55           56.4  New York
# 59  0 hour(s) and 57 minutes                   55           57.0  New York
# 60  0 hour(s) and 57 minutes                   55           57.5   Ontario
# 61  0 hour(s) and 57 minutes                   55           57.5  New York
#
#           Country     Population Direction  Latitude  Longitude  Date
# 50         Canada           1932        NE   45.4500   -75.6833  2011
# 51         Canada           1514        NE   45.1000   -75.2167  2011
# 52  United States           1651        SE   44.7756   -75.1851  2018
# 53  United States           2214        SE   44.8474   -75.1678  2018
# 54  United States           1510        SE   44.3237   -75.7350  2011
# 55         Canada  not available        SW   44.7333   -76.8500  2011
# 56  United States             31        SW   44.2849   -76.0299  2011
# 59  United States             89        SE   44.2782   -76.0083  2011
# 60         Canada           7178        NW   45.4667   -76.4000  2011
# 61  United States            164        SE   44.2847   -75.8458  2011

# %% [markdown]
# ### Filter for towns that meet criteria 3 (not in the United States)

# %%
#Then filter for regions not called Quebec
df3=df2[df2['Country'] != "United States"]
df3.shape
# Out:
# (41, 16)

# %%
df3.tail(10)
# Out:
#           Town Name                                           Web Link  \
# 43        Gananoque  https://www.distantias.com/towns-radius-ganano...
# 45          Russell  https://www.distantias.com/towns-radius-russel...
# 46         Arnprior  https://www.distantias.com/towns-radius-arnpri...
# 47            Ompah  https://www.distantias.com/towns-radius-ompah-...
# 48       Morrisburg  https://www.distantias.com/towns-radius-morris...
# 49       Gloucester  https://www.distantias.com/towns-radius-glouce...
# 50  Rockcliffe Park  https://www.distantias.com/towns-radius-rockcl...
# 51     Chesterville  https://www.distantias.com/towns-radius-cheste...
# 55   Mountain Grove  https://www.distantias.com/towns-radius-mounta...
# 60         Braeside  https://www.distantias.com/towns-radius-braesi...
#
#     Distance Miles  Distance KM  \
# 43           39.85    64.132199
# 45           40.49    65.162177
# 46           40.57    65.290924
# 47           40.70    65.500138
# 48           40.79    65.644979
# 49           41.03    66.031220
# 50           41.30    66.465742
# 51           41.40    66.626676
# 55           42.50    68.396950
# 60           43.34    69.748796
#
#                 Precise Drive time and Directions URL  Approx Drive miles  \
# 43  https://www.distantias.com/distance-from-smith...               48.42
# 45  https://www.distantias.com/distance-from-smith...               49.20
# 46  https://www.distantias.com/distance-from-smith...               49.29
# 47  https://www.distantias.com/distance-from-smith...               49.45
# 48  https://www.distantias.com/distance-from-smith...               49.56
# 49  https://www.distantias.com/distance-from-smith...               49.85
# 50  https://www.distantias.com/distance-from-smith...               50.18
# 51  https://www.distantias.com/distance-from-smith...               50.30
# 55  https://www.distantias.com/distance-from-smith...               51.64
# 60  https://www.distantias.com/distance-from-smith...               52.66
#
#            Approx Drive Time  Assumed Average MPH  Total Minutes   Region  \
# 43  0 hour(s) and 53 minutes                   55           52.8  Ontario
# 45  0 hour(s) and 54 minutes                   55           53.7  Ontario
# 46  0 hour(s) and 54 minutes                   55           53.8  Ontario
# 47  0 hour(s) and 54 minutes                   55           54.0  Ontario
# 48  0 hour(s) and 54 minutes                   55           54.1  Ontario
# 49  0 hour(s) and 54 minutes                   55           54.4  Ontario
# 50  0 hour(s) and 55 minutes                   55           54.7  Ontario
# 51  0 hour(s) and 55 minutes                   55           54.9  Ontario
# 55  0 hour(s) and 56 minutes                   55           56.3  Ontario
# 60  0 hour(s) and 57 minutes                   55           57.5  Ontario
#
#    Country     Population Direction  Latitude  Longitude  Date
# 43  Canada           5194        SW   44.3333   -76.1667  2011
# 45  Canada           3759        NE   45.2600   -75.3600  2011
# 46  Canada          10099        NW   45.4333   -76.3667  2011
# 47  Canada           1675        NW   45.0167   -76.8333  2011
# 48  Canada           2756        NE   44.9000   -75.1833  2011
# 49  Canada         133280        NE   45.4167   -75.6000  2011
# 50  Canada           1932        NE   45.4500   -75.6833  2011
# 51  Canada           1514        NE   45.1000   -75.2167  2011
# 55  Canada  not available        SW   44.7333   -76.8500  2011
# 60  Canada           7178        NW   45.4667   -76.4000  2011

# %% [markdown]
# ### Filter for towns that meet criteria 4 (more than 2,500 residents)

# %% [markdown]
# First must drop any tiny settlements or hamlets (those with 'not available' listed in the population column)

# %%
df4 = df3[df3['Population'] != 'not available']
df4.shape
# Out:
# (35, 16)

# %%
df4.head(10)
# Out:
#          Town Name                                           Web Link  \
# 0     Smiths Falls  https://www.distantias.com/towns-radius-smiths...
# 1     Merrickville  https://www.distantias.com/towns-radius-merric...
# 2            Perth  https://www.distantias.com/towns-radius-perth-...
# 4   Carleton Place  https://www.distantias.com/towns-radius-carlet...
# 5       Kemptville  https://www.distantias.com/towns-radius-kemptv...
# 7         Richmond  https://www.distantias.com/towns-radius-richmo...
# 9          Almonte  https://www.distantias.com/towns-radius-almont...
# 10        Westport  https://www.distantias.com/towns-radius-westpo...
# 11     Stittsville  https://www.distantias.com/towns-radius-stitts...
# 12      Brockville  https://www.distantias.com/towns-radius-brockv...
#
#     Distance Miles  Distance KM  \
# 0             0.00     0.000000
# 1             9.05    14.564527
# 2            10.67    17.171658
# 4            17.09    27.503621
# 5            20.39    32.814443
# 7            21.52    34.632997
# 9            23.63    38.028704
# 10           24.06    38.720720
# 11           24.67    39.702418
# 12           27.35    44.015449
#
#                 Precise Drive time and Directions URL  Approx Drive miles  \
# 0   https://www.distantias.com/distance-from-smith...                0.00
# 1   https://www.distantias.com/distance-from-smith...               10.77
# 2   https://www.distantias.com/distance-from-smith...               13.22
# 4   https://www.distantias.com/distance-from-smith...               21.17
# 5   https://www.distantias.com/distance-from-smith...               24.77
# 7   https://www.distantias.com/distance-from-smith...               26.15
# 9   https://www.distantias.com/distance-from-smith...               28.71
# 10  https://www.distantias.com/distance-from-smith...               29.23
# 11  https://www.distantias.com/distance-from-smith...               29.97
# 12  https://www.distantias.com/distance-from-smith...               33.23
#
#            Approx Drive Time  Assumed Average MPH  Total Minutes   Region  \
# 0    0 hour(s) and 0 minutes                    0            0.0  Ontario
# 1   0 hour(s) and 25 minutes                   26           24.9  Ontario
# 2   0 hour(s) and 21 minutes                   37           21.4  Ontario
# 4   0 hour(s) and 34 minutes                   37           34.3  Ontario
# 5   0 hour(s) and 27 minutes                   55           27.0  Ontario
# 7   0 hour(s) and 29 minutes                   55           28.5  Ontario
# 9   0 hour(s) and 31 minutes                   55           31.3  Ontario
# 10  0 hour(s) and 32 minutes                   55           31.9  Ontario
# 11  0 hour(s) and 33 minutes                   55           32.7  Ontario
# 12  0 hour(s) and 36 minutes                   55           36.3  Ontario
#
#    Country Population Direction  Latitude  Longitude  Date
# 0   Canada       9403        NE   44.9000   -76.0167  2011
# 1   Canada       3067        NE   44.9167   -75.8333  2011
# 2   Canada       6211        SW   44.8833   -76.2333  2011
# 4   Canada      10013        NW   45.1333   -76.1333  2011
# 5   Canada       3532        NE   45.0167   -75.6333  2011
# 7   Canada       3797        NE   45.1833   -75.8333  2011
# 9   Canada       4752        NW   45.2167   -76.2000  2011
# 10  Canada        590        SW   44.6833   -76.4000  2011
# 11  Canada      41350        NE   45.2500   -75.9167  2011
# 12  Canada      23354        SE   44.5833   -75.6833  2011

# %% [markdown]
# Need to next convert the Population column to numeric values

# %%
df4["Population"] = pd.to_numeric(df4["Population"])
df4.dtypes
# Out:
# <ipython-input-136-4ca54877d1da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4["Population"] = pd.to_numeric(df4["Population"])
# Town Name                                 object
# Web Link                                  object
# Distance Miles                           float64
# Distance KM                              float64
# Precise Drive time and Directions URL     object
# Approx Drive miles                       float64
# Approx Drive Time                         object
# Assumed Average MPH                        int64
# Total Minutes                            float64
# Region                                    object
# Country                                   object
# Population                                 int64
# Direction                                 object
# Latitude                                 float64
# Longitude                                float64
# Date                                       int64
# dtype: object

# %% [markdown]
# Now the population values are numerical integers, we can perform the operation of removing towns that contain less than 2,500 residents.

# %%
df5=df4[df4['Population'] > 2500]
df5.shape
# Out:
# (24, 16)

# %%
df5
# Out:
#             Town Name                                           Web Link  \
# 0        Smiths Falls  https://www.distantias.com/towns-radius-smiths...
# 1        Merrickville  https://www.distantias.com/towns-radius-merric...
# 2               Perth  https://www.distantias.com/towns-radius-perth-...
# 4      Carleton Place  https://www.distantias.com/towns-radius-carlet...
# 5          Kemptville  https://www.distantias.com/towns-radius-kemptv...
# 7            Richmond  https://www.distantias.com/towns-radius-richmo...
# 9             Almonte  https://www.distantias.com/towns-radius-almont...
# 11        Stittsville  https://www.distantias.com/towns-radius-stitts...
# 12         Brockville  https://www.distantias.com/towns-radius-brockv...
# 13           Prescott  https://www.distantias.com/towns-radius-presco...
# 15           Manotick  https://www.distantias.com/towns-radius-manoti...
# 18             Kanata  https://www.distantias.com/towns-radius-kanata...
# 20  Mississippi Mills  https://www.distantias.com/towns-radius-pakenh...
# 22             Greely  https://www.distantias.com/towns-radius-greely...
# 23             Nepean  https://www.distantias.com/towns-radius-nepean...
# 24          Britannia  https://www.distantias.com/towns-radius-britan...
# 34           Rockport  https://www.distantias.com/towns-radius-rockpo...
# 37             Ottawa  https://www.distantias.com/towns-radius-ottawa...
# 43          Gananoque  https://www.distantias.com/towns-radius-ganano...
# 45            Russell  https://www.distantias.com/towns-radius-russel...
# 46           Arnprior  https://www.distantias.com/towns-radius-arnpri...
# 48         Morrisburg  https://www.distantias.com/towns-radius-morris...
# 49         Gloucester  https://www.distantias.com/towns-radius-glouce...
# 60           Braeside  https://www.distantias.com/towns-radius-braesi...
#
#     Distance Miles  Distance KM  \
# 0             0.00     0.000000
# 1             9.05    14.564527
# 2            10.67    17.171658
# 4            17.09    27.503621
# 5            20.39    32.814443
# 7            21.52    34.632997
# 9            23.63    38.028704
# 11           24.67    39.702418
# 12           27.35    44.015449
# 13           27.63    44.466064
# 15           28.64    46.091498
# 18           30.47    49.036590
# 20           32.62    52.496671
# 22           33.03    53.156500
# 23           33.11    53.285247
# 24           33.92    54.588813
# 34           37.08    59.674327
# 37           38.87    62.555046
# 43           39.85    64.132199
# 45           40.49    65.162177
# 46           40.57    65.290924
# 48           40.79    65.644979
# 49           41.03    66.031220
# 60           43.34    69.748796
#
#                 Precise Drive time and Directions URL  Approx Drive miles  \
# 0   https://www.distantias.com/distance-from-smith...                0.00
# 1   https://www.distantias.com/distance-from-smith...               10.77
# 2   https://www.distantias.com/distance-from-smith...               13.22
# 4   https://www.distantias.com/distance-from-smith...               21.17
# 5   https://www.distantias.com/distance-from-smith...               24.77
# 7   https://www.distantias.com/distance-from-smith...               26.15
# 9   https://www.distantias.com/distance-from-smith...               28.71
# 11  https://www.distantias.com/distance-from-smith...               29.97
# 12  https://www.distantias.com/distance-from-smith...               33.23
# 13  https://www.distantias.com/distance-from-smith...               33.57
# 15  https://www.distantias.com/distance-from-smith...               34.80
# 18  https://www.distantias.com/distance-from-smith...               37.02
# 20  https://www.distantias.com/distance-from-smith...               39.63
# 22  https://www.distantias.com/distance-from-smith...               40.13
# 23  https://www.distantias.com/distance-from-smith...               40.23
# 24  https://www.distantias.com/distance-from-smith...               41.21
# 34  https://www.distantias.com/distance-from-smith...               45.05
# 37  https://www.distantias.com/distance-from-smith...               47.23
# 43  https://www.distantias.com/distance-from-smith...               48.42
# 45  https://www.distantias.com/distance-from-smith...               49.20
# 46  https://www.distantias.com/distance-from-smith...               49.29
# 48  https://www.distantias.com/distance-from-smith...               49.56
# 49  https://www.distantias.com/distance-from-smith...               49.85
# 60  https://www.distantias.com/distance-from-smith...               52.66
#
#            Approx Drive Time  Assumed Average MPH  Total Minutes   Region  \
# 0    0 hour(s) and 0 minutes                    0            0.0  Ontario
# 1   0 hour(s) and 25 minutes                   26           24.9  Ontario
# 2   0 hour(s) and 21 minutes                   37           21.4  Ontario
# 4   0 hour(s) and 34 minutes                   37           34.3  Ontario
# 5   0 hour(s) and 27 minutes                   55           27.0  Ontario
# 7   0 hour(s) and 29 minutes                   55           28.5  Ontario
# 9   0 hour(s) and 31 minutes                   55           31.3  Ontario
# 11  0 hour(s) and 33 minutes                   55           32.7  Ontario
# 12  0 hour(s) and 36 minutes                   55           36.3  Ontario
# 13  0 hour(s) and 37 minutes                   55           36.6  Ontario
# 15  0 hour(s) and 38 minutes                   55           38.0  Ontario
# 18  0 hour(s) and 40 minutes                   55           40.4  Ontario
# 20  0 hour(s) and 43 minutes                   55           43.2  Ontario
# 22  0 hour(s) and 44 minutes                   55           43.8  Ontario
# 23  0 hour(s) and 44 minutes                   55           43.9  Ontario
# 24  0 hour(s) and 45 minutes                   55           45.0  Ontario
# 34  0 hour(s) and 49 minutes                   55           49.2  Ontario
# 37  0 hour(s) and 52 minutes                   55           51.5  Ontario
# 43  0 hour(s) and 53 minutes                   55           52.8  Ontario
# 45  0 hour(s) and 54 minutes                   55           53.7  Ontario
# 46  0 hour(s) and 54 minutes                   55           53.8  Ontario
# 48  0 hour(s) and 54 minutes                   55           54.1  Ontario
# 49  0 hour(s) and 54 minutes                   55           54.4  Ontario
# 60  0 hour(s) and 57 minutes                   55           57.5  Ontario
#
#    Country  Population Direction  Latitude  Longitude  Date
# 0   Canada        9403        NE   44.9000   -76.0167  2011
# 1   Canada        3067        NE   44.9167   -75.8333  2011
# 2   Canada        6211        SW   44.8833   -76.2333  2011
# 4   Canada       10013        NW   45.1333   -76.1333  2011
# 5   Canada        3532        NE   45.0167   -75.6333  2011
# 7   Canada        3797        NE   45.1833   -75.8333  2011
# 9   Canada        4752        NW   45.2167   -76.2000  2011
# 11  Canada       41350        NE   45.2500   -75.9167  2011
# 12  Canada       23354        SE   44.5833   -75.6833  2011
# 13  Canada        4284        SE   44.7167   -75.5167  2011
# 15  Canada        4486        NE   45.2400   -75.6800  2011
# 18  Canada      101760        NE   45.3333   -75.9000  2011
# 20  Canada       13163        NW   45.3333   -76.2833  2011
# 22  Canada        9049        NE   45.2600   -75.5700  2011
# 23  Canada      170544        NE   45.3467   -75.7700  2011
# 24  Canada        6692        NE   45.3667   -75.8000  2011
# 34  Canada        2689        SE   44.3667   -75.9333  2011
# 37  Canada      947000        NE   45.4167   -75.7000  2011
# 43  Canada        5194        SW   44.3333   -76.1667  2011
# 45  Canada        3759        NE   45.2600   -75.3600  2011
# 46  Canada       10099        NW   45.4333   -76.3667  2011
# 48  Canada        2756        NE   44.9000   -75.1833  2011
# 49  Canada      133280        NE   45.4167   -75.6000  2011
# 60  Canada        7178        NW   45.4667   -76.4000  2011

# %% [markdown]
# ### Filter for towns that meet criteria 5 (less than 50,000 residents)

# %%
df6=df5[df5['Population'] < 50000]
df6.shape
# Out:
# (20, 16)

# %%
df6.head(10)
# Out:
#          Town Name                                           Web Link  \
# 0     Smiths Falls  https://www.distantias.com/towns-radius-smiths...
# 1     Merrickville  https://www.distantias.com/towns-radius-merric...
# 2            Perth  https://www.distantias.com/towns-radius-perth-...
# 4   Carleton Place  https://www.distantias.com/towns-radius-carlet...
# 5       Kemptville  https://www.distantias.com/towns-radius-kemptv...
# 7         Richmond  https://www.distantias.com/towns-radius-richmo...
# 9          Almonte  https://www.distantias.com/towns-radius-almont...
# 11     Stittsville  https://www.distantias.com/towns-radius-stitts...
# 12      Brockville  https://www.distantias.com/towns-radius-brockv...
# 13        Prescott  https://www.distantias.com/towns-radius-presco...
#
#     Distance Miles  Distance KM  \
# 0             0.00     0.000000
# 1             9.05    14.564527
# 2            10.67    17.171658
# 4            17.09    27.503621
# 5            20.39    32.814443
# 7            21.52    34.632997
# 9            23.63    38.028704
# 11           24.67    39.702418
# 12           27.35    44.015449
# 13           27.63    44.466064
#
#                 Precise Drive time and Directions URL  Approx Drive miles  \
# 0   https://www.distantias.com/distance-from-smith...                0.00
# 1   https://www.distantias.com/distance-from-smith...               10.77
# 2   https://www.distantias.com/distance-from-smith...               13.22
# 4   https://www.distantias.com/distance-from-smith...               21.17
# 5   https://www.distantias.com/distance-from-smith...               24.77
# 7   https://www.distantias.com/distance-from-smith...               26.15
# 9   https://www.distantias.com/distance-from-smith...               28.71
# 11  https://www.distantias.com/distance-from-smith...               29.97
# 12  https://www.distantias.com/distance-from-smith...               33.23
# 13  https://www.distantias.com/distance-from-smith...               33.57
#
#            Approx Drive Time  Assumed Average MPH  Total Minutes   Region  \
# 0    0 hour(s) and 0 minutes                    0            0.0  Ontario
# 1   0 hour(s) and 25 minutes                   26           24.9  Ontario
# 2   0 hour(s) and 21 minutes                   37           21.4  Ontario
# 4   0 hour(s) and 34 minutes                   37           34.3  Ontario
# 5   0 hour(s) and 27 minutes                   55           27.0  Ontario
# 7   0 hour(s) and 29 minutes                   55           28.5  Ontario
# 9   0 hour(s) and 31 minutes                   55           31.3  Ontario
# 11  0 hour(s) and 33 minutes                   55           32.7  Ontario
# 12  0 hour(s) and 36 minutes                   55           36.3  Ontario
# 13  0 hour(s) and 37 minutes                   55           36.6  Ontario
#
#    Country  Population Direction  Latitude  Longitude  Date
# 0   Canada        9403        NE   44.9000   -76.0167  2011
# 1   Canada        3067        NE   44.9167   -75.8333  2011
# 2   Canada        6211        SW   44.8833   -76.2333  2011
# 4   Canada       10013        NW   45.1333   -76.1333  2011
# 5   Canada        3532        NE   45.0167   -75.6333  2011
# 7   Canada        3797        NE   45.1833   -75.8333  2011
# 9   Canada        4752        NW   45.2167   -76.2000  2011
# 11  Canada       41350        NE   45.2500   -75.9167  2011
# 12  Canada       23354        SE   44.5833   -75.6833  2011
# 13  Canada        4284        SE   44.7167   -75.5167  2011

# %% [markdown]
# ### Drop unrequired columns, then reset the index

# %%
df_shortlist=df6[['Town Name','Population','Distance KM','Latitude','Longitude']]
df_shortlist.reset_index(drop=True)
# Out:
#             Town Name  Population  Distance KM  Latitude  Longitude
# 0        Smiths Falls        9403     0.000000   44.9000   -76.0167
# 1        Merrickville        3067    14.564527   44.9167   -75.8333
# 2               Perth        6211    17.171658   44.8833   -76.2333
# 3      Carleton Place       10013    27.503621   45.1333   -76.1333
# 4          Kemptville        3532    32.814443   45.0167   -75.6333
# 5            Richmond        3797    34.632997   45.1833   -75.8333
# 6             Almonte        4752    38.028704   45.2167   -76.2000
# 7         Stittsville       41350    39.702418   45.2500   -75.9167
# 8          Brockville       23354    44.015449   44.5833   -75.6833
# 9            Prescott        4284    44.466064   44.7167   -75.5167
# 10           Manotick        4486    46.091498   45.2400   -75.6800
# 11  Mississippi Mills       13163    52.496671   45.3333   -76.2833
# 12             Greely        9049    53.156500   45.2600   -75.5700
# 13          Britannia        6692    54.588813   45.3667   -75.8000
# 14           Rockport        2689    59.674327   44.3667   -75.9333
# 15          Gananoque        5194    64.132199   44.3333   -76.1667
# 16            Russell        3759    65.162177   45.2600   -75.3600
# 17           Arnprior       10099    65.290924   45.4333   -76.3667
# 18         Morrisburg        2756    65.644979   44.9000   -75.1833
# 19           Braeside        7178    69.748796   45.4667   -76.4000

# %% [markdown]
# This represent our final processed, cleaned and finished dataframe, ready for leveraging and evaluation using foresquare

# %% [markdown]
# ## Import additional Required libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Create a map centered on Smith's Falls, with all towns that meet the minimum criteria superimposed on top

# %% [markdown]
# Obtain longitudes and latitudes from top row in dataframe

# %%
latitude = df_shortlist.iloc[0,3] 
longitude = df_shortlist.iloc[0,4]

# %% [markdown]
# Create map with suitable zoom level

# %%
map_smithsFalls = folium.Map(location=[latitude, longitude], zoom_start=8)

# %% [markdown]
# Add markers to map

# %%
for lat, lng, town in zip(df_shortlist['Latitude'], df_shortlist['Longitude'], df_shortlist['Town Name']):
    label = '{}'.format(town)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_smithsFalls)  
    
map_smithsFalls
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_6f3d8a422057420b980533d3d3d75fa7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6f3d8a422057420b980533d3d3d75fa7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6f3d8a422057420b980533d3d3d75fa7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_6f3d8a422057420b980533d3d3d75fa7%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B44.9%2C-76.0167%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%208%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ### Define my Foursquare Credentials and Version

# %%
CLIENT_ID = 'CCKOQHSERN1KJLQR44C4RZBZ4NH4QO4ELA3EU4FBLIMKBEGL'
CLIENT_SECRET = 'E0FLMAGE44ZKOJ44VXSHPX2J4NZDCPX34NJRKQIFDKEEJ2HO' 
VERSION = '20180605'
LIMIT = 100

# %% [markdown]
# ### Create a function to iteratively explore the Towns

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=3000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Town', 
                  'Town Latitude', 
                  'Town Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Run the above function on each town and create a new dataframe called shortlist_venues

# %%
shortlist_venues = getNearbyVenues(names=df_shortlist['Town Name'],
                                   latitudes=df_shortlist['Latitude'],
                                   longitudes=df_shortlist['Longitude']
                                  )
# Out:
# Smiths Falls
# Merrickville
# Perth
# Carleton Place
# Kemptville
# Richmond
# Almonte
# Stittsville
# Brockville
# Prescott
# Manotick
# Mississippi Mills
# Greely
# Britannia
# Rockport
# Gananoque
# Russell
# Arnprior
# Morrisburg
# Braeside

# %% [markdown]
# Examine the size and print out a sample of the resulting dataframe

# %%
print(shortlist_venues.shape)
shortlist_venues
# Out:
# (412, 7)
#              Town  Town Latitude  Town Longitude  \
# 0    Smiths Falls        44.9000        -76.0167
# 1    Smiths Falls        44.9000        -76.0167
# 2    Smiths Falls        44.9000        -76.0167
# 3    Smiths Falls        44.9000        -76.0167
# 4    Smiths Falls        44.9000        -76.0167
# ..            ...            ...             ...
# 407      Braeside        45.4667        -76.4000
# 408      Braeside        45.4667        -76.4000
# 409      Braeside        45.4667        -76.4000
# 410      Braeside        45.4667        -76.4000
# 411      Braeside        45.4667        -76.4000
#
#                                        Venue  Venue Latitude  Venue Longitude  \
# 0               Coffee Culture Cafe & Eatery       44.901396       -76.021224
# 1                            TD Canada Trust       44.900042       -76.020867
# 2                                  Pizza Hut       44.891743       -76.030096
# 3           Andress' Your Independent Grocer       44.892481       -76.026833
# 4                             The Beer Store       44.893694       -76.027683
# ..                                       ...             ...              ...
# 407  Dan Leblanc Bulldozing & Septic Systems       45.465448       -76.406106
# 408             Robyn Lamont Massage Therapy       45.467556       -76.408664
# 409                          My Country Home       45.471506       -76.376277
# 410             Darlene's Place in the Prior       45.449172       -76.375622
# 411             Darlene's Place in the Prior       45.448997       -76.375036
#
#                  Venue Category
# 0                          Café
# 1                          Bank
# 2                   Pizza Place
# 3                 Grocery Store
# 4                    Beer Store
# ..                          ...
# 407  Construction & Landscaping
# 408              Massage Studio
# 409                   Gift Shop
# 410                   Gift Shop
# 411                   Gift Shop
#
# [412 rows x 7 columns]

# %% [markdown]
# Examine how many venues were returned for each town

# %%
shortlist_venues.groupby('Town').count()
# Out:
#                    Town Latitude  Town Longitude  Venue  Venue Latitude  \
# Town
# Almonte                        6               6      6               6
# Arnprior                      24              24     24              24
# Braeside                       5               5      5               5
# Britannia                    100             100    100             100
# Brockville                    44              44     44              44
# Carleton Place                30              30     30              30
# Gananoque                     21              21     21              21
# Greely                         4               4      4               4
# Kemptville                    24              24     24              24
# Manotick                      19              19     19              19
# Merrickville                   7               7      7               7
# Mississippi Mills              8               8      8               8
# Morrisburg                    10              10     10              10
# Perth                         11              11     11              11
# Prescott                      18              18     18              18
# Richmond                       4               4      4               4
# Rockport                      17              17     17              17
# Russell                        4               4      4               4
# Smiths Falls                  26              26     26              26
# Stittsville                   30              30     30              30
#
#                    Venue Longitude  Venue Category
# Town
# Almonte                          6               6
# Arnprior                        24              24
# Braeside                         5               5
# Britannia                      100             100
# Brockville                      44              44
# Carleton Place                  30              30
# Gananoque                       21              21
# Greely                           4               4
# Kemptville                      24              24
# Manotick                        19              19
# Merrickville                     7               7
# Mississippi Mills                8               8
# Morrisburg                      10              10
# Perth                           11              11
# Prescott                        18              18
# Richmond                         4               4
# Rockport                        17              17
# Russell                          4               4
# Smiths Falls                    26              26
# Stittsville                     30              30

# %% [markdown]
# Check how many unique categories can be curated from all the returned venues

# %%
print('There are {} unique categories.'.format(len(shortlist_venues['Venue Category'].unique())))
# Out:
# There are 82 unique categories.
